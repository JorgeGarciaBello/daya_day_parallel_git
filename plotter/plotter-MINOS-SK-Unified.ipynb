# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import neutrino_plotter as nplt
import neutrino_filtering_data as nf
import module_1 as myplt
import importlib
importlib.reload(nplt)
importlib.reload(nf)
importlib.reload(myplt)
# Out:
# <module 'module_1' from '/home/jogabell/Documentos/neutrinos/plotter/module_1.py'>

# %%
MINOS = pd.read_table('my_whole_minos_tunned.dat',names=['dm32','s2_t13','s2_t23','ji'],delim_whitespace=True)

# %%
SK    = pd.read_table('SK.dat',names=['dm32','s2_t13','s2_t23','ji'],delim_whitespace=True)

# %%
itrpl=1
params=['s2_t23','dm32']
size=2000
title=''
MINOS_1=myplt.plotter_SK_confidence_regions(0,itrpl,SK,params,size,title)
# Out:
# {'dm32_min': 0.0024317269076305215, 's2_t13_min': 0.011204819277108428, 's2_t23_min': 0.5474397590361446, 'ji_min': 0.0}
# {'dm32_min': 0.0024317269076305215, 's2_t13_min': 0.011204819277108428, 's2_t23_min': 0.5474397590361446, 'ji_min': 0.0}
# {'new_ji_after_itrpl': -0.00042610418723100345, 'new_ji': 0.0, 'dm32': 0.0024344672336168082, 's2_t23': 0.5469609804902451}
# {'dm32_min': 0.0024317269076305215, 's2_t13_min': 0.011204819277108428, 's2_t23_min': 0.5474397590361446, 'ji_min': 0.0}

# %%
itrpl=1
params=['s2_t23','dm32']
size=3000
title=''
MINOS_1=myplt.plotter_SK_confidence_regions(0,itrpl,MSRD,params,size,title)
# Out:
# {'dm32_min': 0.002469076305220884, 's2_t13_min': 0.02240963855421687, 's2_t23_min': 0.5972389558232931, 'ji_min': 0.0}
# {'dm32_min': 0.002469076305220884, 's2_t13_min': 0.02240963855421687, 's2_t23_min': 0.5972389558232931, 'ji_min': 0.0}
# {'new_ji_after_itrpl': 1.934106998358401e-06, 'new_ji': 0.0, 'dm32': 0.002468856285428476, 's2_t23': 0.5971823941313772}
# {'dm32_min': 0.002469076305220884, 's2_t13_min': 0.02240963855421687, 's2_t23_min': 0.5972389558232931, 'ji_min': 0.0}
