# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import neutrino_plotter as nplt
import neutrino_filtering_data as nf
import module_1 as myplt
import importlib
importlib.reload(nplt)
importlib.reload(nf)
importlib.reload(myplt)
# Out:
# <module 'module_1' from '/home/jogabell/Documentos/neutrinos/plotter/module_1.py'>

# %%
MSRD = pd.read_table('MSRD.dat',names=['dm32','s2_t13','s2_t23','ji'],delim_whitespace=True)

# %%
intrpl = 1
params             = ['dm32','s2_t13']
MSRD_dm32_s2_t13   = myplt.ploter_UNIFIED_confidence_regions(intrpl, MSRD ,params,4500,'new')
# Out:
# {'dm32_min': 0.002469076305220884, 's2_t13_min': 0.02240963855421687, 's2_t23_min': 0.5972389558232931, 'ji_min': 175.90846996340932}
# {'dm32_min': 0.002469076305220884, 's2_t13_min': 0.02240963855421687, 's2_t23_min': 0.5972389558232931, 'ji_min': 175.90846996340932}
# {'new_ji_after_itrpl': -0.017104791701208946, 'new_ji': 0.0, 'dm32': 0.002469726605912425, 's2_t13': 0.02230773505223383}

# %%
Mmin  = {'dm32_min': 0.002493975903614457, 's2_t13_min': 0.01587349397590361, 's2_t23_min': 0.3746987951807229, 'ji_min': 0.0}
SKmin = {'dm32_min': 0.0024317269076305215, 's2_t13_min': 0.011204819277108428, 's2_t23_min': 0.5474397590361446, 'ji_min': 1.883507184240231}
#SKmin = {'dm32_min': 0.0024, 's2_t13_min': 0.010, 's2_t23_min': 0.5474397590361446, 'ji_min': 1.883507184240231}
Rmin  = {'dm32_min': 0.002680722891566265, 's2_t13_min': 0.02303212851405623, 's2_t23_min': 0.3, 'ji_min': 16.65170867164629}
Dmin  = {'dm32_min': 0.0024566265060240967, 's2_t13_min': 0.02209839357429719, 's2_t23_min': 0.42916666666666653, 'ji_min': 151.0269343411842}
Umin  = {'dm32_min': 0.002469076305220884, 's2_t13_min': 0.02240963855421687, 's2_t23_min': 0.5972389558232931, 'ji_min': 0.0}
params  = ['s2_t13','dm32']
myplt.ploter_SPECIAL_1(Mmin,SKmin,Rmin,Dmin,Umin,MSRD_dm32_s2_t13,params,'new')

# %%
intrpl = 1
params             = ['dm32','s2_t13']
MSRD_dm32_s2_t13   = myplt.ploter_UNIFIED_confidence_regions(intrpl, MSRD ,params,4500,'new')

myplt.ploter_SPECIAL_1(Mmin,SKmin,Rmin,Dmin,Umin,MSRD_dm32_s2_t13,params,'new')
