# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import neutrino_plotter as nplt
import neutrino_filtering_data as nf
import module_1 as myplt
import importlib
importlib.reload(nplt)
importlib.reload(nf)
importlib.reload(myplt)
# Out:
# <module 'module_1' from '/home/jogabell/Documentos/neutrinos/plotter/module_1.py'>

# %%
# MINOS data
MINOS_dat68 = pd.read_table('MINOS_data/minos_from_webplot_cl_68.dat',names=['s2_t23','dm32'],delim_whitespace=True)
MINOS_dat90 = pd.read_table('data_webplot.dat',names=['s2_t23','dm32'],delim_whitespace=True)

# %%
# SK data
SK_dat68 = pd.read_table('sk_nh_ih/SK_SPECIAL_2_cl_68.dat', names=['s2_t23','dm32'], delim_whitespace=True)
SK_dat90 = pd.read_table('sk_nh_ih/SK_SPECIAL_2_cl_90.dat', names=['s2_t23','dm32'], delim_whitespace=True)

#SK_dat68 = pd.read_table('sk_nh_ih/sk_t13_zero_cl_68.dat', names=['s2_t23','dm32'], delim_whitespace=True)
#SK_dat90 = pd.read_table('sk_nh_ih/sk_t13_zero_cl_90.dat', names=['s2_t23','dm32'], delim_whitespace=True)

# %%
# GLOBAL data
GBL_dat68 = pd.read_table('global/global_cl_68.dat', names=['s2_t23','dm32'], delim_whitespace=True)
GBL_dat90 = pd.read_table('global/global_cl_90.dat', names=['s2_t23','dm32'], delim_whitespace=True)

# %%
Mmin={'dm32_min': 0.002493975903614457, 's2_t13_min': 0.01587349397590361, 's2_t23_min': 0.3746987951807229, 'ji_min': 0.0}
SKmin={'dm32_min': 0.0024317269076305215, 's2_t13_min': 0.011204819277108428, 's2_t23_min': 0.5474397590361446, 'ji_min': 1.883507184240231}
# t13 = 0
#SKmin={'dm32_min': 0.002195180722891567, 's2_t13_min': 0.0, 's2_t23_min': 0.525652610441767, 'ji_min': 2.8369135692335385}
Umin={'dm32_min': 0.002469076305220884, 's2_t13_min': 0.02240963855421687, 's2_t23_min': 0.5972389558232931, 'ji_min': 0.0}
dfs1=[MINOS_dat68,MINOS_dat90]
dfs2=[SK_dat68,SK_dat90]
dfs3=[GBL_dat68,GBL_dat90]
params=['s2_t23','dm32']
myplt.ploter_SPECIAL_2(Mmin,SKmin,Umin,dfs1,dfs2,dfs3,params,'new')
