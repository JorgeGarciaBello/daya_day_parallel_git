# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import neutrino_plotter as nplt
import neutrino_filtering_data as nf
import module_1 as myplt
import importlib
importlib.reload(nplt)
importlib.reload(nf)
importlib.reload(myplt)
# Out:
# <module 'module_1' from '/home/jogabell/Documentos/neutrinos/plotter/module_1.py'>

# %%
# MINOS data
MINOS_dat90 = pd.read_table('data_webplot.dat',names=['s2_t23','dm32'],delim_whitespace=True)

# %%
# MINOS+SK (t13=0)
#MSK_t13_zero_68 = pd.read_table('global/global_cl_68.dat', names=['s2_t23','dm32'], delim_whitespace=True)
MSK_t13_zero_90 = pd.read_table('MINOS+SK_T13_ZERO/MSK_t13_zero_s2_t23_vs_dm32_cl_90.dat', names=['s2_t23','dm32'], delim_whitespace=True)
MSK_t13_90 = pd.read_table('MINOS+SK_T13_ZERO/MSK_s2_t23_vs_dm32_cl_90.dat', names=['s2_t23','dm32'], delim_whitespace=True)

# %%
# GLOBAL data
#GBL_dat68 = pd.read_table('global/global_cl_68.dat', names=['s2_t23','dm32'], delim_whitespace=True)
GBL_dat90 = pd.read_table('global/global_cl_90.dat', names=['s2_t23','dm32'], delim_whitespace=True)

# %%
dfs1=MINOS_dat90
dfs2=MSK_t13_zero_90 #SK_s2_t23
dfs3=GBL_dat90
params=['s2_t23','dm32']
Mmin={'dm32_min': 0.002493975903614457, 's2_t13_min': 0.01587349397590361, 's2_t23_min': 0.3746987951807229, 'ji_min': 0.0}
# t13=0
MSKmin={'dm32_min': 0.0024317269076305215, 's2_t13_min': 0.0, 's2_t23_min': 0.5661144578313253, 'ji_min': 8.327716614431289}
#MSKmin={'dm32_min': 0.0024317269076305215, 's2_t13_min': 0.0102710843373494, 's2_t23_min': 0.5832329317269076, 'ji_min': 4.29938148447455}
Umin={'dm32_min': 0.002469076305220884, 's2_t13_min': 0.02240963855421687, 's2_t23_min': 0.5972389558232931, 'ji_min': 0.0}
myplt.ploter_SPECIAL_4(Mmin,MSKmin,Umin,dfs1,dfs2,dfs3,params,'new')
